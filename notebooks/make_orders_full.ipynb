# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data_folder = '~/instacart_data/'
orders = pd.read_csv(data_folder + 'orders.csv')
orders_prior = pd.read_csv(data_folder + 'order_products__prior.csv')
orders_train = pd.read_csv(data_folder + 'order_products__train.csv')

# %%
orders.loc[orders['eval_set'] == 'test'].head()
# Out:
#      order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 38    2774568        3     test            13          5                 15
# 44     329954        4     test             6          3                 12
# 53    1528013        6     test             4          3                 16
# 96    1376945       11     test             8          6                 11
# 102   1356845       12     test             6          1                 20
#
#      days_since_prior_order
# 38                     11.0
# 44                     30.0
# 53                     22.0
# 96                      8.0
# 102                    30.0

# %%
orders.loc[orders['user_id'] == 3].head(30)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 26   1374495        3    prior             1          1                 14
# 27    444309        3    prior             2          3                 19
# 28   3002854        3    prior             3          3                 16
# 29   2037211        3    prior             4          2                 18
# 30   2710558        3    prior             5          0                 17
# 31   1972919        3    prior             6          0                 16
# 32   1839752        3    prior             7          0                 15
# 33   3225766        3    prior             8          0                 17
# 34   3160850        3    prior             9          0                 16
# 35    676467        3    prior            10          3                 16
# 36    521107        3    prior            11          0                 18
# 37   1402502        3    prior            12          1                 15
# 38   2774568        3     test            13          5                 15
#
#     days_since_prior_order
# 26                     NaN
# 27                     9.0
# 28                    21.0
# 29                    20.0
# 30                    12.0
# 31                     7.0
# 32                     7.0
# 33                     7.0
# 34                     7.0
# 35                    17.0
# 36                    11.0
# 37                    15.0
# 38                    11.0

# %%
orders.loc[orders['user_id'] == 4]
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 39   3343014        4    prior             1          6                 11
# 40   2030307        4    prior             2          4                 11
# 41    691089        4    prior             3          4                 15
# 42     94891        4    prior             4          5                 13
# 43   2557754        4    prior             5          5                 13
# 44    329954        4     test             6          3                 12
#
#     days_since_prior_order
# 39                     NaN
# 40                    19.0
# 41                    21.0
# 42                    15.0
# 43                     0.0
# 44                    30.0

# %%
orders.loc[orders['user_id'] == 4]
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 39   3343014        4    prior             1          6                 11
# 40   2030307        4    prior             2          4                 11
# 41    691089        4    prior             3          4                 15
# 42     94891        4    prior             4          5                 13
# 43   2557754        4    prior             5          5                 13
# 44    329954        4     test             6          3                 12
#
#     days_since_prior_order
# 39                     NaN
# 40                    19.0
# 41                    21.0
# 42                    15.0
# 43                     0.0
# 44                    30.0

# %%
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
orders_prior.loc[orders_prior['order_id'] == 3343014]
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 31695751   3343014       36606                  1          0
# 31695752   3343014        7350                  2          0
# 31695753   3343014       35469                  3          0
# 31695754   3343014        2707                  4          0

# %%
orders_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df = pd.concat((orders_train, orders_prior), axis=0)
df = orders.merge(df, on='order_id', how='left')

# %%
#df.to_csv('orders_full.csv')

# %%
orders_train.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
df['user_id'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: user_id, dtype: int64

# %%
train = df.loc[df['eval_set'] == 'test']
